# %%
import skimage.io
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd

# %%
folder='/Users/oliviaruge/Desktop/Labs/Ruthazer/Methods_projects/cropped_images//'
#(green-red)/red
files = [i for i in listdir(folder) if "tif" in i]
files.sort()
data = {"animal":[],"percent green":[], "slices":[]}
red = {"min":np.inf, "max":0}
green = {"min":np.inf, "max":0}
'''
for idx in range(0,len(files),2):
    red_chan = skimage.io.imread(folder+files[idx])
    green_chan = skimage.io.imread(folder+files[idx+1])
    red_min = np.min(red_chan)
    red_max = np.max(red_chan)
    green_min = np.min(green_chan)
    green_max = np.max(green_chan)
    
    if red["min"]> red_min :
        red["min"]= red_min  
    if red["max"]<red_max:
        red["max"]=red_max
        
    if green["min"]>green_min:
        green["min"]=green_min
    if green["max"]<green_max:
        green["max"]=green_max
print(red , green)
'''
for idx in range(0,len(files),2):
    print(files[idx])
    print(files[idx+1])
    red_chan = skimage.io.imread(folder+files[idx])
    green_chan = skimage.io.imread(folder+files[idx+1])

    animal_min = np.min([red_chan,green_chan],axis=(0,2,3)).reshape((red_chan.shape[0],1,1))
    animal_max = np.max([red_chan,green_chan],axis=(0,2,3)).reshape((red_chan.shape[0],1,1))
    
    n_red = (red_chan-animal_min)/animal_max
    n_green = (green_chan-animal_min)/animal_max
    n_red[n_red<np.percentile(n_red,2)]=np.nan
    n_green[n_green<np.percentile(n_green,2)]=np.nan
    
    percent_green = np.nanmean([n_green-n_red/n_red])

    data["animal"].append(files[idx])
    data["percent green"].append(percent_green)
    data["slices"].append(len(red_chan))
# Out:
# A1_electroporation_cldu_channel1_cropped.tif
# A1_electroporation_cldu_channel2_cropped.tif
# A1_electroporation_may9_channel1_cropped.tif
# A1_electroporation_may9_channel2_cropped.tif
# A1_lipofection_cldu_channel1_cropped.tif
# A1_lipofection_cldu_channel2_cropped.tif
# A1_lipofection_cldu_may19_channel1_cropped.tif
# A1_lipofection_cldu_may19_channel2_cropped.tif
# A1_positive_control_channel1_cropped.tif
# A1_positive_control_channel2_cropped.tif
# A1_positive_control_may19_channel1_cropped.tif
# A1_positive_control_may19_channel2_cropped.tif
# A1_tubulin_clduneg_channel1_cropped.tif
# A1_tubulin_clduneg_channel2_cropped.tif
# A2_electroporation_cldu_channel1_cropped.tif
# A2_electroporation_cldu_channel2_cropped.tif
# A2_electroporation_may9_channel1_cropped.tif
# A2_electroporation_may9_channel2_cropped.tif
# A2_lipofection_cldu_channel1_cropped.tif
# A2_lipofection_cldu_channel2_cropped.tif
# A2_lipofection_cldu_may19_channel1_cropped.tif
# ...

# %%
red_chan = skimage.io.imread(folder+files[idx])
green_chan = skimage.io.imread(folder+files[idx+1])

animal_min = np.min([red_chan,green_chan],axis=(0,2,3)).reshape((red_chan.shape[0],1,1))
animal_max = np.max([red_chan,green_chan],axis=(0,2,3)).reshape((red_chan.shape[0],1,1))

n_red = (red_chan-animal_min)/animal_max
n_green = (green_chan-animal_min)/animal_max
np.percentile(n_green,2)
n_green[n_green<np.percentile(n_green,2)]=np.nan

# %%
out_path="/Users/oliviaruge/Desktop/Labs/Ruthazer/Methods_projects//"

df = pd.DataFrame(data)
df.to_csv(out_path+'cldu_percentage.csv', index=False)

# %%
    red_min = np.min(red_chan,axis=(1,2)).reshape((red_chan.shape[0],1,1))
    green_min = np.min(green_chan,axis=(1,2)).reshape((red_chan.shape[0],1,1))
    red_max = np.max(red_chan,axis=(1,2)).reshape((red_chan.shape[0],1,1))
    green_max = np.max(green_chan,axis=(1,2)).reshape((red_chan.shape[0],1,1))
    n_red = (red_chan-red_min)/red_max
    n_red[n_red<np.percentile(n_red,2)]=np.nan
    n_green = (green_chan-green_min)/green_max
    n_green[n_green<np.percentile(n_green,2)]=np.nan
    percent_green = np.nanmean([n_green-n_red/n_red])
